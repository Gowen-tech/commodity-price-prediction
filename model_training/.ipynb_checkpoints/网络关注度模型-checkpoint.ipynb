# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing

df0 = pd.read_csv("../棕榈油/棕榈油结算价和起酥油index的比对.csv", usecols=[2]).rename(columns={"棕榈油结算价":"price"})
df1 = pd.read_csv("../棕榈油/棕榈油结算价和起酥油index的比对.csv", usecols=[1]).rename(columns={"index":"qisu"})
df2 = pd.read_csv("../棕榈油/棕榈油结算价和棕榈树index的比对.csv", usecols=[1]).rename(columns={"index":"tree"})
df3 = pd.read_csv("../棕榈油/棕榈油结算价和棕榈树index的比对.csv", usecols=[1]).rename(columns={"index":"palm"})
df4 = pd.read_csv("../棕榈油/棕榈油结算价和棕榈油的危害index的比对.csv", usecols=[1]).rename(columns={"index":"harm"})
df = pd.concat([df0, df1, df2, df3, df4], axis=1)

train_X = []
train_y = []
train_price = df["price"].tolist()
train_X.append(train_price[:-3])
train_X.append(train_price[1:-2])
train_X.append(train_price[2:-1])

train_qisu = df["qisu"].tolist()
train_X.append(train_qisu[2:-1])

train_tree = df["tree"].tolist()
train_X.append(train_tree[2:-1])

train_palm = df["palm"].tolist()
train_X.append(train_palm[:-3])
train_X.append(train_palm[1:-2])
train_X.append(train_palm[2:-1])

train_harm = df["harm"].tolist()
train_X.append(train_harm[:-3])
train_X.append(train_harm[1:-2])
train_X.append(train_harm[2:-1])

train_X = np.array(train_X).transpose()

train_y.append(train_price[3:])
train_y = np.array(train_y).transpose()

min_max_scaler = preprocessing.MinMaxScaler(feature_range=(-1, 1), copy=True)
train_X = min_max_scaler.fit_transform(train_X)
train_y = min_max_scaler.fit_transform(train_y)

# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing

df_tst_p = pd.read_csv("大连期货交易所大宗农产品DRR表.csv", usecols=[0,3])[344:].rename(columns={"棕榈油":"price"})
df_tst1 = pd.read_csv("index_to_gwl^o^.csv", usecols=[0,4]).rename(columns={"log-diff-起酥油":"qisu"})
df_tst2 = pd.read_csv("index_to_gwl^o^.csv", usecols=[0,2]).rename(columns={"log-diff-棕榈树":"tree"})
df_tst3 = pd.read_csv("index_to_gwl^o^.csv", usecols=[0,1]).rename(columns={"log-diff-棕榈":"palm"})
df_tst4 = pd.read_csv("index_to_gwl^o^.csv", usecols=[0,3]).rename(columns={"log-diff-棕榈油的危害":"harm"})
df_tst1 = pd.merge(df_tst_p, df_tst1, on="date").iloc[:, 1:]
df_tst2 = pd.merge(df_tst_p, df_tst2, on="date").iloc[:, 1:]
df_tst3 = pd.merge(df_tst_p, df_tst3, on="date").iloc[:, 1:]
df_tst4 = pd.merge(df_tst_p, df_tst4, on="date").iloc[:, 1:]
df_tst = pd.concat([df_tst1, df_tst2["tree"], df_tst3["palm"], df_tst4["harm"]], axis=1)

test_X = []
test_y = []
test_date = []

test_date.append(df_tst_p["date"].tolist()[3:])
test_date = np.array(test_date).transpose()

test_price = df_tst["price"].tolist()
test_X.append(test_price[:-3])
test_X.append(test_price[1:-2])
test_X.append(test_price[2:-1])

test_qisu = df_tst["qisu"].tolist()
test_X.append(test_qisu[2:-1])

test_tree = df_tst["tree"].tolist()
test_X.append(test_tree[2:-1])

test_palm = df_tst["palm"].tolist()
test_X.append(test_palm[:-3])
test_X.append(test_palm[1:-2])
test_X.append(test_palm[2:-1])

test_harm = df_tst["harm"].tolist()
test_X.append(test_harm[:-3])
test_X.append(test_harm[1:-2])
test_X.append(test_harm[2:-1])

test_X = np.array(test_X).transpose()

test_y.append(test_price[3:])
test_y = np.array(test_y).transpose()

min_max_scaler = preprocessing.MinMaxScaler(feature_range=(-1, 1), copy=True)
test_X = min_max_scaler.fit_transform(test_X)
test_y = min_max_scaler.fit_transform(test_y)

# %%
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt

svr_lin = SVR(kernel='linear')
svr_sigmoid = SVR(kernel='sigmoid')

y_lin = svr_lin.fit(train_X, train_y).predict(test_X)
y_rbf = SVR().fit(train_X, train_y).predict(test_X)
y_sig = svr_sigmoid.fit(train_X, train_y).predict(test_X)

rmse_lin = mean_squared_error(test_y, y_lin)
rmse_rbf = mean_squared_error(test_y, y_rbf)
rmse_sig = mean_squared_error(test_y, y_sig)
print("Model w/ Keywords Index(棕榈油)")
print("Root mean squared error of linear: ", rmse_lin)
print("Root mean squared error of RBF: ", rmse_rbf)
print("Root mean squared error of sigmoid: ", rmse_sig)


plt.plot(np.arange(0, len(test_date)), test_y,  color='orange', label='fact')
plt.plot(np.arange(0, len(test_date)), y_rbf, color='blue', linewidth=2, label='predict')

plt.xticks(())
plt.yticks(())
plt.xlabel('date')
plt.ylabel('volatility')
plt.legend()

plt.gcf().set_size_inches(15,5)

print()

n_lin = 0
for i in range(0,len(test_y)):
    if y_lin[i] >= 0 and test_y[i] >= 0:
        n_lin += 1
    elif  y_lin[i] < 0 and test_y[i] < 0:
        n_lin += 1
    else:
        n_lin = n_lin
acc_lin = n_lin/len(test_y)
n_rbf = 0
for i in range(0,len(test_y)):
    if y_rbf[i] >= 0 and test_y[i] >= 0:
        n_rbf += 1
    elif  y_rbf[i] < 0 and test_y[i] < 0:
        n_rbf += 1
    else:
        n_rbf = n_rbf
acc_rbf = n_rbf/len(test_y)
n_sig = 0
for i in range(0,len(test_y)):
    if y_sig[i] >= 0 and test_y[i] >= 0:
        n_rbf += 1
    elif  y_sig[i] < 0 and test_y[i] < 0:
        n_sig += 1
    else:
        n_sig = n_sig
acc_sig = n_sig/len(test_y)
print("Accuracy of linear: ", acc_lin)
print("Accuracy of RBF: ", acc_rbf)
print("Accuracy of sigmoid: ", acc_sig)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# Model w/ Keywords Index(棕榈油)
# Root mean squared error of linear:  0.10184320085098009
# Root mean squared error of RBF:  0.09550032857863514
# Root mean squared error of sigmoid:  0.10433559234983462
#
# Accuracy of linear:  0.6758241758241759
# Accuracy of RBF:  0.6483516483516484
# Accuracy of sigmoid:  0.2692307692307692
